# %% [markdown]
# <a href="https://colab.research.google.com/github/shrouk2233/projects/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SVM Implementation**

# %%
# Step 1: Import libraries
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# To display plots in the notebook
# %matplotlib inline

# Step 2: Load dataset
data = load_breast_cancer()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.Series(data.target)

# %%
df = X.copy()
df['target'] = y


df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
#Check for missing values
print("Missing values per column:")
print(X.isnull().sum())
# Out:
# Missing values per column:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# dtype: int64

# %%
# Check for duplicate rows
duplicates = df[df.duplicated()]

# Print the duplicate rows
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [mean radius, mean texture, mean perimeter, mean area, mean smoothness, mean compactness, mean concavity, mean concave points, mean symmetry, mean fractal dimension, radius error, texture error, perimeter error, area error, smoothness error, compactness error, concavity error, concave points error, symmetry error, fractal dimension error, worst radius, worst texture, worst perimeter, worst area, worst smoothness, worst compactness, worst concavity, worst concave points, worst symmetry, worst fractal dimension, target]
# Index: []
#
# [0 rows x 31 columns]

# %%
#Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42,stratify=y)

# %%
#Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#EDA (exploratory data analysis )
print(df.info())

print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
# Correlation matrix
plt.figure(figsize=(18,18))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
# (benign vs malignant)
sns.countplot(x='target', data=df,)
plt.title("Distribution of Target Classes")
plt.xticks([0, 1], ['Malignant (0)', 'Benign (1)'])
plt.show()

# %%
 #(benign vs malignant) according to smoothness error(largest corr to target)
plt.figure(figsize=(6,4))
sns.histplot(data=df, x='smoothness error', hue='target', kde=True, bins=30)
plt.title('Distribution of Mean Radius by Target Class')
plt.xlabel('Mean Radius')
plt.legend(labels=['Malignant', 'Benign'])
plt.show()

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

#  dif kernels
kernels = ['linear', 'poly', 'rbf']
results = {}

fig, axes = plt.subplots(1, 3, figsize=(18, 5))


for idx, kernel in enumerate(kernels):
    print(f"\n--- Kernel: {kernel} ---")

    # Construct the model
    model = SVC(kernel=kernel, C=1.0, gamma='scale', random_state=42,probability=True)


    model.fit(X_train, y_train)


    y_pred = model.predict(X_test)

    # Calculate accuracy
    train_acc=accuracy_score(y_train, model.predict(X_train))
    acc = accuracy_score(y_test, y_pred)

    print(f"Accuracy: {acc}")
    print(f"Confusion Matrix:\n{confusion_matrix(y_test, y_pred)}")
    print(f"Classification Report:\n{classification_report(y_test, y_pred)}")
    y_prob = model.predict_proba(X_test)[:, 1]
    y_train_prob = model.predict_proba(X_train)[:, 1]
    results[kernel] = {
        'y_true_train':y_train,
        'y_pred': y_pred,
        'y_proba_train':y_train_prob,
        'model': model,
        'y_true': y_test,
        'y_proba': y_prob,
        'accuracy': acc ,
        'train_accuracy':train_acc,
    }

    # Plot confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[idx],
                xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
    axes[idx].set_title(f'Confusion Matrix - {kernel.capitalize()} Kernel')
    axes[idx].set_xlabel('Predicted')
    axes[idx].set_ylabel('Actual')

# Adjust layout to avoid overlap
plt.tight_layout()
plt.show()
# Out:
# --- Kernel: linear ---
# Accuracy: 0.9824561403508771
# Confusion Matrix:
# [[ 62   2]
#  [  1 106]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98        64
#            1       0.98      0.99      0.99       107
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171
#
#
# --- Kernel: poly ---
# Accuracy: 0.8947368421052632
# Confusion Matrix:
# [[ 46  18]
#  [  0 107]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.72      0.84        64
#            1       0.86      1.00      0.92       107
#
#     accuracy                           0.89       171
#    macro avg       0.93      0.86      0.88       171
# weighted avg       0.91      0.89      0.89       171
#
#
# --- Kernel: rbf ---
# Accuracy: 0.9766081871345029
# ...

# %%
# Grid Search for Polynomial SVM
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Define parameter grid
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': ['scale', 'auto', 0.01, 0.1],
    'degree': [2, 3, 4],
    'coef0': [0.0, 1.0, 10.0]
}

# Create base model
poly_svm = SVC(kernel='poly', probability=True, random_state=42)

# Setup GridSearchCV
grid_search = GridSearchCV(
    estimator=poly_svm,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    verbose=1
)

# Perform grid search
grid_search.fit(X_train, y_train)

# Get best parameters and model
best_params = grid_search.best_params_
best_score = grid_search.best_score_
best_model = grid_search.best_estimator_

print(f"Best Parameters: {best_params}")
print(f"Best Cross-Validation Score: {best_score:.4f}")

# Evaluate on test set
y_pred = best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred)
print(f"Test Accuracy with Best Model: {test_accuracy:.4f}")
print(f"Confusion Matrix:\n{confusion_matrix(y_test, y_pred)}")
print(f"Classification Report:\n{classification_report(y_test, y_pred)}")

# Visualize confusion matrix for best model
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
           xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.title('Confusion Matrix - Best Polynomial SVM')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Optional: add the best model to the results dictionary
results['poly_grid'] = {
    'model': best_model,
    'y_true': y_test,
    'y_pred': y_pred,
    'y_proba': best_model.predict_proba(X_test)[:, 1],
    'accuracy': test_accuracy,
    'train_accuracy': accuracy_score(y_train, best_model.predict(X_train)),
    'y_true_train': y_train,
    'y_proba_train': best_model.predict_proba(X_train)[:, 1]
}
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# Best Parameters: {'C': 0.1, 'coef0': 10.0, 'degree': 2, 'gamma': 0.01}
# Best Cross-Validation Score: 0.9799
# Test Accuracy with Best Model: 0.9766
# Confusion Matrix:
# [[ 61   3]
#  [  1 106]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97        64
#            1       0.97      0.99      0.98       107
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.97      0.97       171
# weighted avg       0.98      0.98      0.98       171

# %%
import matplotlib.pyplot as plt

kernels = list(results.keys())
accuracies = [results[kernel]['accuracy'] for kernel in kernels]

plt.figure(figsize=(8, 5))
colors = ['skyblue', 'purple', 'lightpink']
plt.bar(kernels, accuracies, color=colors[:len(kernels)])
plt.ylim(0.85, 1.0)
plt.title("SVM Accuracy for Different Kernels")
plt.xlabel("Kernel Type")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# # **Neural Network Implementation**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import numpy as np


callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)
]

activations = ['relu', 'sigmoid', 'tanh']
models = {}
histories = {}
results_NT = {}

# Create, train and evaluate models with different activation functions
for activation in activations:
    print(f"\nTraining model with {activation} activation:")

    models[activation] = Sequential([
        Dense(32, activation=activation, input_shape=(X_train.shape[1],)),
        BatchNormalization(),
        Dropout(0.3),
        Dense(16, activation=activation),
        BatchNormalization(),
        Dropout(0.2),
        Dense(1, activation='sigmoid')
    ])

    models[activation].compile(
        optimizer=Adam(learning_rate=0.001),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    histories[activation] = models[activation].fit(
        X_train, y_train,
        epochs=50,
        batch_size=32,
        validation_split=0.2,
        callbacks=callbacks,
        verbose=1
    )

    loss, accuracy = models[activation].evaluate(X_test, y_test, verbose=0)
    y_pred_prob = models[activation].predict(X_test)
    y_pred = (y_pred_prob > 0.5).astype("int32").flatten()

    results_NT[activation] = {
        'test_accuracy': accuracy,
        'test_loss': loss,
        'y_pred': y_pred,
        'y_pred_prob': y_pred_prob,
        'val_loss': min(histories[activation].history['val_loss']),
        'val_accuracy': max(histories[activation].history['val_accuracy'])
    }

    print(f"{activation.capitalize()} Model Test Accuracy: {accuracy:.4f}")
# Out:
# Training model with relu activation:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.3733 - loss: 1.1320 - val_accuracy: 0.6375 - val_loss: 0.6372 - learning_rate: 0.0010
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5548 - loss: 0.7566 - val_accuracy: 0.7375 - val_loss: 0.5030 - learning_rate: 0.0010
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7336 - loss: 0.5298 - val_accuracy: 0.8375 - val_loss: 0.4099 - learning_rate: 0.0010
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7454 - loss: 0.4857 - val_accuracy: 0.9000 - val_loss: 0.3433 - learning_rate: 0.0010
# ...

# %%
# Plot all loss curves in one figure
plt.figure(figsize=(15, 8))

plt.subplot(1, 2, 1)
for activation, history in histories.items():
    plt.plot(history.history['loss'], linestyle='--', label=f'{activation} - Train')
    plt.plot(history.history['val_loss'], label=f'{activation} - Val')
plt.title('Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# %%
plt.figure()
for activation in activations:
    plt.plot(histories[activation].history['accuracy'], label=f'{activation.capitalize()} Train Accuracy')
    plt.plot(histories[activation].history['val_accuracy'], label=f'{activation.capitalize()} Validation Accuracy')
plt.title('Accuracy Curves for All Activations')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for i, activation in enumerate(activations):
    cm = confusion_matrix(y_test, results_NT[activation]['y_pred'])
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Malignant', 'Benign'])
    disp.plot(ax=axes[i], cmap='Blues', values_format='d')
    axes[i].set_title(f'{activation.capitalize()} Model')
plt.tight_layout()
plt.show()

# %%
print("\nSummary of Results:")
for activation in activations:
    print(f"{activation.capitalize()} - Test Accuracy: {results_NT[activation]['test_accuracy']:.4f}, "
          f"Test Loss: {results_NT[activation]['test_loss']:.4f}, "
          f"Best Val Accuracy: {results_NT[activation]['val_accuracy']:.4f}, "
          f"Best Val Loss: {results_NT[activation]['val_loss']:.4f}")
# Out:
# Summary of Results:
# Relu - Test Accuracy: 0.9649, Test Loss: 0.0830, Best Val Accuracy: 0.9875, Best Val Loss: 0.0567
# Sigmoid - Test Accuracy: 0.9825, Test Loss: 0.0675, Best Val Accuracy: 0.9875, Best Val Loss: 0.0381
# Tanh - Test Accuracy: 0.9942, Test Loss: 0.0593, Best Val Accuracy: 0.9875, Best Val Loss: 0.0450

# %%
# Find best model
best_activation = min(results_NT.items(), key=lambda x: x[1]['val_loss'])[0]
print(f"\nBest performing activation function: {best_activation} (validation loss: {results_NT[best_activation]['val_loss']:.4f})")
# Print classification report for best model
print(f"\nClassification Report for Best Model ({best_activation.capitalize()}):")
print(classification_report(y_test, results_NT[best_activation]['y_pred'], target_names=['Malignant', 'Benign']))
# Out:
# Best performing activation function: sigmoid (validation loss: 0.0381)
#
# Classification Report for Best Model (Sigmoid):
#               precision    recall  f1-score   support
#
#    Malignant       0.98      0.97      0.98        64
#       Benign       0.98      0.99      0.99       107
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171

# %% [markdown]
# # **Model Comparison and Analysis**

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import precision_recall_fscore_support
from sklearn.svm import SVC
import seaborn as sns

print("\nDetailed Performance Metrics for Neural Networks:")
print(f"{'Activation':<10} {'Accuracy':<10} {'Precision':<10} {'Recall':<10} {'F1-score':<10}")
print("-" * 60)

nn_metrics = {}

for activation in activations:
    y_true = y_test
    y_pred = results_NT[activation]['y_pred']

    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred, zero_division=0)
    rec = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)

    nn_metrics[activation] = {
        'accuracy': acc,
        'precision': prec,
        'recall': rec,
        'f1_score': f1
    }

    print(f"{activation:<10} {acc:<10.4f} {prec:<10.4f} {rec:<10.4f} {f1:<10.4f}")
# Out:
# Detailed Performance Metrics for Neural Networks:
# Activation Accuracy   Precision  Recall     F1-score
# ------------------------------------------------------------
# relu       0.9649     0.9720     0.9720     0.9720
# sigmoid    0.9825     0.9815     0.9907     0.9860
# tanh       0.9942     0.9907     1.0000     0.9953

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
print("\n\nComparison between SVMs and Neural Networks:")
print(f"{'Model':<15} {'Accuracy':<10} {'Precision':<10} {'Recall':<10} {'F1-score':<10}")
print("-" * 60)

comparison_data = []
kernels = ['linear', 'poly_grid', 'rbf']

for kernel in kernels:
    acc = accuracy_score(y_test, results[kernel]['y_pred'])
    prec, rec, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary', zero_division=0)

    print(f"SVM-{kernel:<11} {acc:<10.4f} {prec:<10.4f} {rec:<10.4f} {f1:<10.4f}")
    comparison_data.append({
        'Model': f'SVM-{kernel}',
        'Accuracy': acc,
        'Precision': prec,
        'Recall': rec,
        'F1-score': f1
    })

for activation in activations:
    metrics = nn_metrics[activation]
    print(f"NN-{activation:<11} {metrics['accuracy']:<10.4f} {metrics['precision']:<10.4f} {metrics['recall']:<10.4f} {metrics['f1_score']:<10.4f}")
    comparison_data.append({
        'Model': f'NN-{activation}',
        'Accuracy': metrics['accuracy'],
        'Precision': metrics['precision'],
        'Recall': metrics['recall'],
        'F1-score': metrics['f1_score']
    })
# Out:
# Comparison between SVMs and Neural Networks:
# Model           Accuracy   Precision  Recall     F1-score
# ------------------------------------------------------------
# SVM-linear      0.9825     0.9725     0.9907     0.9815
# SVM-poly_grid   0.9766     0.9725     0.9907     0.9815
# SVM-rbf         0.9766     0.9725     0.9907     0.9815
# NN-relu        0.9649     0.9720     0.9720     0.9720
# NN-sigmoid     0.9825     0.9815     0.9907     0.9860
# NN-tanh        0.9942     0.9907     1.0000     0.9953

# %%
comparison_df = pd.DataFrame(comparison_data)
plt.figure(figsize=(10, 5))
sns.heatmap(comparison_df.set_index('Model'), annot=True, cmap='Blues', fmt='.2f')
plt.title('Comparison of SVM and Neural Networks Performance Metrics')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

comparison_df = pd.DataFrame(comparison_data)
plt.figure(figsize=(12, 6))
pd.plotting.parallel_coordinates(comparison_df, 'Model', colormap=plt.get_cmap("tab10"))
plt.title('Parallel Coordinates Plot: SVM vs Neural Networks Performance Metrics')
plt.ylabel('Score')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(10, 8))

for kernel in kernels:
    # ROC curve for training data
    y_true_train = results[kernel]['y_true_train']
    y_prob_train = results[kernel]['y_proba_train']
    fpr_train, tpr_train, _ = roc_curve(y_true_train, y_prob_train)
    roc_auc_train = auc(fpr_train, tpr_train)
    plt.plot(fpr_train, tpr_train, label=f'SVM-{kernel} Train (AUC = {roc_auc_train:.2f})')

    # ROC curve for testing data
    y_true_test = results[kernel]['y_true']
    y_prob_test = results[kernel]['y_proba']
    fpr_test, tpr_test, _ = roc_curve(y_true_test, y_prob_test)
    roc_auc_test = auc(fpr_test, tpr_test)
    plt.plot(fpr_test, tpr_test, label=f'SVM-{kernel} Test (AUC = {roc_auc_test:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for SVM Kernels (Train vs Test)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

svm_kernels = ['linear', 'poly_grid', 'rbf']

train_accuracies = [results[k]['accuracy'] for k in svm_kernels]
test_accuracies  = [results[k]['train_accuracy'] for k in svm_kernels]

x = np.arange(len(svm_kernels))
width = 0.35

plt.figure(figsize=(8, 6))
plt.bar(x - width/2, train_accuracies, width, label='Train Accuracy')
plt.bar(x + width/2, test_accuracies, width, label='Test Accuracy')

plt.xticks(x, [f'SVM-{k}' for k in svm_kernels])
plt.ylim(0, 1)
plt.ylabel('Accuracy')
plt.title('SVM Train vs Test Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Overfitting Check for Both SVM and Neural Network
print("\n--- Overfitting Check Results ---")
for kernel in svm_kernels:
    train_acc = results[kernel]['train_accuracy']
    test_acc = results[kernel]['accuracy']
    gap = train_acc - test_acc
    if gap > 0.1:
        print(f" Overfitting detected in SVM-{kernel} (Gap: {gap:.2f})")
    else:
        print(f" No significant overfitting in SVM-{kernel} (Gap: {gap:.2f})")

for activation in ['relu', 'sigmoid', 'tanh']:
    history = histories[activation]
    final_train = history.history['accuracy'][-1]
    final_val = history.history['val_accuracy'][-1]
    gap = final_train - final_val
    if gap > 0.1:
        print(f" Overfitting detected in NN-{activation.upper()} (Gap: {gap:.2f})")
    else:
        print(f" No significant overfitting in NN-{activation.upper()} (Gap: {gap:.2f})")
# Out:
# --- Overfitting Check Results ---
#  No significant overfitting in SVM-linear (Gap: 0.01)
#  No significant overfitting in SVM-poly_grid (Gap: 0.01)
#  No significant overfitting in SVM-rbf (Gap: 0.01)
#  No significant overfitting in NN-RELU (Gap: -0.01)
#  No significant overfitting in NN-SIGMOID (Gap: -0.01)
#  No significant overfitting in NN-TANH (Gap: -0.03)
